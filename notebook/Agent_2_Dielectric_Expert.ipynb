# %% [markdown]
# # Agent 2 Dielectric Expert 워크플로우 테스트
#
# 이 노트북은 `Dielectric Expert` (절연 파괴/노후화 전문가)의 독립적인 워크플로우를 테스트합니다.
#
# ## 주요 기능
# - 테스트 이미지 로드
# - Dielectric Expert 그래프 실행 (Step 1 -> Step 2 -> Step 3)
# - 결과 분석 및 리포트 출력

# %%
# 1. 초기 설정 및 라이브러리 임포트
import sys
import os
from pathlib import Path
import json
import base64

# 프로젝트 루트 경로 설정
project_root = Path.cwd().parent if Path.cwd().name == "notebook" else Path.cwd()
sys.path.insert(0, str(project_root))

# 환경 변수 로드
from dotenv import load_dotenv
load_dotenv(project_root / ".env")

print(f"✓ 프로젝트 루트: {project_root}")
# Out:
# ✓ 프로젝트 루트: c:\Users\loidn\Documents\Projects\P_04_Scope

# %%
# 2. 테스트 이미지 준비
from src.utils import find_data_directory

try:
    data_dir = find_data_directory()
    test_image_name = "IMG_8113.jpg"
    test_image_path = Path(data_dir) / test_image_name
    
    if not test_image_path.exists():
        # 이미지가 없으면 첫 번째 가능한 이미지 사용
        image_files = list(Path(data_dir).glob("*.png")) + list(Path(data_dir).glob("*.jpg"))
        if image_files:
            test_image_path = image_files[0]
            print(f"⚠️ {test_image_name}을 찾을 수 없어 {test_image_path.name}을 사용합니다.")
        else:
            raise FileNotFoundError("테스트할 이미지가 없습니다.")
            
    print(f"✓ 테스트 이미지: {test_image_path}")
except Exception as e:
    print(f"❌ 오류: {e}")
# Out:
# ✓ 테스트 이미지: c:\Users\loidn\Documents\Projects\P_04_Scope\data\IMG_8113.jpg

# %%
# 3. Payload 생성 함수
def create_payload(image_path):
    with open(image_path, 'rb') as f:
        image_data = f.read()
    
    ext = Path(image_path).suffix.lower()
    mime_type = 'image/png' if ext == '.png' else 'image/jpeg'
    image_base64 = base64.b64encode(image_data).decode('utf-8')
    
    return [
        {"text": "이미지를 분석하세요."},
        {"inline_data": {"mime_type": mime_type, "data": image_base64}}
    ]

# %%
# 4. Dielectric Expert 실행
from src.graphs.dielectric_expert_graph import dielectric_expert_wrapper_node
from src.state import InvestigationState

print("Dielectric Expert 분석 시작...")

payload = create_payload(test_image_path)

# InvestigationState 모의 구성
mock_state = InvestigationState(
    payload=payload,
    expert_reports=[],
    expert_analysis_results={},
    expert_confidence_scores={},
    expert_evidence={},
    final_verdict=None,
    errors=[],
    dielectric_cached_image_data=None # 캐시 초기화
)

try:
    result = dielectric_expert_wrapper_node(mock_state)
    
    print("\n✓ 분석 완료!")
    print("=" * 60)
    
    # 결과 출력
    reports = result.get("expert_reports", [])
    if reports:
        print(reports[0])
    else:
        print("리포트가 생성되지 않았습니다.")
        
    print("=" * 60)
    print("세부 분석 결과:")
    analysis_results = result.get("expert_analysis_results", {}).get("dielectric", {})
    print(json.dumps(analysis_results, indent=2, ensure_ascii=False))
    
except Exception as e:
    print(f"❌ 실행 중 오류 발생: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Dielectric Expert 분석 시작...
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: analyze_carbonization_depth_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmpn4vzgb44.jpg'})
#    └─ 📊 [Tool Output]: {"internal_heating_detected": false, "carbonization_depth": "unknown", "carbonization_direction": "unknown", "conductor_fusion": false, "fusion_description": "도체와 절연체가 열에 의해 완전히 융합된 명확한 시각적 증거가 관찰되지 않음.", "cross_section_visible": false, "confidence": 30, "reasoning": "전선의 수직 단면(Cross-section)이 촬영되지 ...
#
# 🧠 [Thought]:
# 제공된 이미지 분석 결과, 절연체의 **탄화 심도 및 방향은 '판단 불가(Unknown)'**입니다.
#
# 상세 분석 내용은 다음과 같습니다:
#
# *   **내부 발열 감지 여부:** 감지되지 않음 (False)
# *   **탄화 심도 및 방향:** 판단 불가 (Unknown)
# *   **도체 융합 여부:** 도체와 절연체가 열에 의해 융합된 명확한 시각적 증거가 관찰되지 않음
# *   **분석 근거:** 전선의 수직 단면(Cross-section)이 촬영되지 않아 내부와 외부의 탄화 정도를 비교 분석할 수 없습니다. 원거리 이미지상의 표면 탄화 현상만으로는 이것이 내부 발열(과전류 등)에 의한 것인지 외부 열원에 의한 것인지 확정하는 것이 불가능합니다.
# *   **신뢰도:** 30% (단면 미확인으로 인한 낮은 신뢰도)
#
# **Final Answer: 이미지 분석 결과, 전선의 수직 단면 부재로 인해 탄화 심도와 방향을 특정할 수 없으며(Unknown), 내부 발열 여부 또한 현재 데이터로는 확정이 불가능합니다.**
#
# ============================================================================
#
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: enhance_image (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmpn4vzgb44.jpg'})
#    └─ 📊 [Tool Output]: 이미지가 이미 선명하여 향상 작업을 건너뜁니다 (Variance: 417.8).
# - 원본 크기: 1568x1176
# 🛠️ [Tool Call]: crop_image (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmpn4vzgb44.jpg'})
#    └─ 📊 [Tool Output]: 이미지 크롭 완료
# - 원본 크기: 1568x1176
# - 크롭된 크기: 1568x1176
# 🛠️ [Tool Call]: analyze_swelling_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmpn4vzgb44.jpg'})
#    └─ 📊 [Tool Output]: {"swelling_detected": false, "spongy_texture_detected": false, "porous_structure_detected": false, "graphitization_detected": false, "melted_texture_detected": false, "texture_type": "rough", "texture_description": "절연체 표면이 검게 탄화되어 불규칙하고 거친 질감을 나타내고 있으나, 내부 가스 방출에 의한 명확한 다공성(Pore) 구조나 깊이감 있는 스펀지 현상은...
#
# 🧠 [Thought]:
# Final Answer: 이미지 분석 결과, 해당 절연체에서는 **스펀지 현상, 흑연화, 단순 용융 현상이 모두 관찰되지 않았습니다.** 상세 분석 내용은 다음과 같습니다.
#
# 1.  **질감 분석 (Rough):** 절연체 표면이 검게 탄화되어 불규칙하고 거친 질감을 나타내고 있으나, 이는 탄화 과정에서 발생하는 일반적인 현상입니다.
# 2.  **스펀지 현상 (미검출):** 내부 가스 방출에 의한 명확한 다공성(Pore) 구조나 유의미한 부풀어 오름(Swelling)이 확인되지 않습니다.
# 3.  **흑연화 및 용융 (미검출):** 금속성 광택을 띠는 흑연화 층이나, 열에 의해 매끄럽게 흘러내린 용융 흔적도 식별되지 않습니다.
# 4.  **기타 특이사항:** 탄화된 절연층이 조각나거나 도체로부터 박리되는 현상이 관찰되며, 전체적으로 무광택의 거친 탄화물 상태를 유지하고 있습니다.
#
# **결론:** 본 이미지는 열에 의한 절연체의 단순 탄화 및 물리적 파손 상태로 판단되며, 화재 감식 등에서 중요하게 다뤄지는 특이 조직(스펀지, 흑연화 등)은 형성되지 않은 것으로 분석됩니다. (분석 신뢰도: 85%)
#
# ============================================================================
#
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: analyze_global_aging_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmpn4vzgb44.jpg'})
#    └─ 📊 [Tool Output]: {"global_aging_detected": true, "widespread_cracking": true, "discoloration_pattern": "전선 전반에 걸쳐 피복의 흑색 탄화 및 불규칙한 탈색 패턴이 관찰됨", "hardening_detected": true, "brittleness_detected": true, "localized_damage_only": false, "confidence": 90, "reasoning": "단락 지점뿐만 아니라 이미지 내에 노출된 전선 피복 전반에서 미세 균열과 경화 현상이 관찰됩...
#
# 🧠 [Thought]:
# Final Answer: 이미지(C:\Users\loidn\AppData\Local\Temp\tmpn4vzgb44.jpg) 분석 결과, 전선 전체에 걸친 **광역적 노후화 징후가 뚜렷하게 관찰**됩니다. 상세 분석 내용은 다음과 같습니다.
#
# 1.  **노후화 판정:** 광역적 노후화 감지됨 (확신도: 90%)
# 2.  **주요 관찰 징후:**
#     *   **균열 및 경화:** 단락 지점뿐만 아니라 전선 피복 전반에서 미세한 균열과 재질의 경화(Hardening) 및 취성화(Brittleness)가 확인됩니다.
#     *   **변색 패턴:** 전선 전반에 걸쳐 피복의 흑색 탄화 및 불규칙한 탈색 패턴이 나타납니다.
# 3.  **분석 의견:** 이러한 징후는 특정 지점의 기계적 손상이 아닌, 장기간에 걸친 열적 노후화로 인해 절연체 전체의 물리적 성질이 저하되었음을 의미합니다. 절연 성능이 크게 낮아진 상태로 판단됩니다.
# 4.  **주요 분석 영역(Bounding Boxes):** 이미지 내 [305, 0, 405, 438], [540, 0, 630, 442] 등 전선의 여러 구간에서 동일한 노후화 패턴이 식별되었습니다.
#
# ============================================================================
#
#
# ✓ 분석 완료!
# ============================================================
# [DielectricAge 전문가 리포트]
# ## 절연열화 (Insulation Degradation) 판별 전문가 리포트
#
# **전문가:** 절연열화 분석 전문가
#
# **분석 결과 요약:**
# 절연열화 판정 신뢰도: 26%
#
# **단계별 분석 결과:**
#
# **1. 탄화의 심도 분석:**
# - 내부 발열 탐지: ✗ 미탐지
# - 탄화 방향: unknown
# - 탄화 깊이: unknown
# - 도체 융착: ✗ 미확인
# - 신뢰도: 30%
#
# **2. 스펀지 현상 및 부풀어 오름 분석:**
# - 스펀지/부풀어 오름 탐지: ✗ 미탐지
# - 질감 유형: rough
# - 흑연화 탐지: ✗ 미탐지
# - 질감 설명: 절연체 표면이 검게 탄화되어 불규칙하고 거친 질감을 나타내고 있으나, 내부 가스 방출에 의한 명확한 다공성(Pore) 구조나 깊이감 있는 스펀지 현상은 관찰되지 않음. 또한 금속성 광택을 띠는 흑연화 층이나 열에 의해 매끄럽게 흘러내린 용융 흔적도 식별이 어려움.
# - 신뢰도: 85%
#
# **3. 광역적 노후화 징후 분석:**
# - 광역적 노후화 탐지: ✓ 탐지됨
# - 광역적 균열: True
# - 변색 패턴: 전선 전반에 걸쳐 피복의 흑색 탄화 및 불규칙한 탈색 패턴이 관찰됨
# - 신뢰도: 90%
#
# **증거:**
# - Step 3: 광역적 노후화 확인 - 전선 전반에 걸쳐 피복의 흑색 탄화 및 불규칙한 탈색 패턴이 관찰됨
#
# **결론:**
# 제공된 데이터를 기반으로 분석한 결과, 절연열화에 의한 단락 가능성이 있습니다 (신뢰도: 26%).
# ============================================================
# 세부 분석 결과:
# {
#   "step1": {
#     "internal_heating_detected": false,
#     "carbonization_depth": "unknown",
#     "carbonization_direction": "unknown",
#     "conductor_fusion": false,
#     "fusion_description": "도체와 절연체가 열에 의해 완전히 융합된 명확한 시각적 증거가 관찰되지 않음.",
#     "cross_section_visible": false,
#     "confidence": 30,
#     "reasoning": "전선의 수직 단면(Cross-section)이 촬영되지 않아 내부와 외부의 탄화 정도를 비교 분석할 수 없음. 원거리 이미지상의 표면 탄화만으로는 내부 발열 여부를 확정하는 것이 불가능함.",
#     "bboxes": [
#       [
#         310,
#         15,
#         412,
#         452
#       ],
#       [
#         305,
#         475,
#         595,
#         988
#       ],
#       [
#         512,
#         12,
#         698,
#         455
#       ]
#     ],
#     "thinking_process": {
#       "reasoning_text": "고분자 재료 및 전기 절연 파괴 분석 전문가로서, 제공된 이미지를 바탕으로 절연체의 탄화 상태와 방향성을 분석합니다.\n\n### 1단계: 시각적 요소 추출 및 이미지 품질 평가\n*   **이미지 구성:** 다수의 연선(Stranded wire)과 전기 단자(Terminal) 부품이 포함된 소손 시료입니다.\n*   **단면 확인(Cross-section):** 전선의 절연 피복을 수직으로 절단하여 내부와 외부의 탄화 정도를 비교할 수 있는 **단면 이미지가 존재하지 않습니다.**\n*   **피복 상태:** 전선 전반에 걸쳐 검은색 탄화(Carbonization) 현상이 관찰되며, 일부 구간에서는 피복이 완전히 소실되어 구리 도체가 노출되어 있습니다.\n*   **이미지 품질:** 전체적인 소손 형태는 식별 가능하나, 탄화의 미세한 방향성(내부→외부 또는 외부→내부)을 확정하기 위한 매크로 촬영(근접 촬영) 정보가 부족합니다.\n\n### 2단계: 특징 서술\n*   **탄화 깊이 및 방향:** 피복 표면이 불규칙하게 거칠고 검게 변해 있으나, 이것이 도체와의 접촉면(내부)에서 시작된 것인지 표면(외부)에서 시작된 것인지 구분할 수 있는 기하학적 단서가 보이지 않습니다. 따라서 방향성은 **'판단 불가(Unknown)'**입니다.\n*   **도체 상태:** 노출된 구리 도체는 일부 광택을 유지하고 있으나, 단자 근처의 도체는 열에 의한 변색이 관찰됩니다.\n*   **융착(Fusion) 여부:** 도체 가닥 사이나 도체와 절연체 사이에 열로 인해 녹아붙은 융착(Fused) 징후는 본 이미지의 해상도와 각도에서는 명확히 식별되지 않습니다.\n\n### 3단계: 논리적 추론\n*   **내부 발열 가능성:** 내부 발열(과전류, 반단선 등)에 의한 탄화라면 도체와 맞닿은 내부 절연물이 먼저 탄화되어 공동(Void)이 생기거나 도체에 탄화물이 강력하게 고착되어야 합니다. 현재 사진으로는 이를 확인할 수 없습니다.\n*   **외부 화재 가능성:** 외부 열원에 의한 경우 피복 표면부터 균일하게 탄화됩니다. 현재 피복의 소손 상태가 불규칙하나, 이것만으로 외부 화재를 확정할 수도 없습니다.\n*   **결론 도출의 한계:** 절연 파괴 분석에서 가장 중요한 '내-외부 탄화 구배(Carbonization Gradient)'를 확인할 수 있는 단면 데이터가 없으므로, 열원의 위치를 추정하는 것은 과학적 근거가 부족한 추측에 불과합니다.\n\n### 4단계: 최종 판단 및 대안적 가능성\n*   **최종 판단:** 시각적 데이터 부족으로 인한 **판단 불가**.\n*   **확신도:** 30% (단면 미확인으로 인한 낮은 신뢰도).\n*   **대안적 가능성:** \n    1. 외부 화염에 의한 직접적인 피복 연소 및 물리적 단절.\n    2. 단자 연결 부위의 접촉 저항 증가에 의한 국부적 발열 및 절연 파괴.\n\n---\n\n```json"
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   },
#   "step2": {
#     "swelling_detected": false,
#     "spongy_texture_detected": false,
#     "porous_structure_detected": false,
#     "graphitization_detected": false,
#     "melted_texture_detected": false,
#     "texture_type": "rough",
#     "texture_description": "절연체 표면이 검게 탄화되어 불규칙하고 거친 질감을 나타내고 있으나, 내부 가스 방출에 의한 명확한 다공성(Pore) 구조나 깊이감 있는 스펀지 현상은 관찰되지 않음. 또한 금속성 광택을 띠는 흑연화 층이나 열에 의해 매끄럽게 흘러내린 용융 흔적도 식별이 어려움.",
#     "cracking_pattern": "탄화된 절연층의 조각화 및 도체로부터의 박리 현상이 관찰됨.",
#     "confidence": 85,
#     "reasoning": "표면의 거칠기는 탄화 과정에서 발생하는 일반적인 현상이며, 스펀지 현상으로 확정할 수 있는 유의미한 부풀어 오름이나 기공 구조가 부족함. 전체적으로 무광택의 거친 탄화물 상태를 유지하고 있음.",
#     "bboxes": [
#       [
#         312,
#         5,
#         385,
#         439
#       ],
#       [
#         305,
#         680,
#         400,
#         880
#       ],
#       [
#         570,
#         5,
#         630,
#         430
#       ],
#       [
#         458,
#         705,
#         510,
#         885
#       ]
#     ],
#     "thinking_process": {
#       "reasoning_text": "### 분석 과정 요약\n\n본 분석은 고분자 절연체의 열화 및 파손 메커니즘을 규명하기 위해 시각적 데이터를 기반으로 수행되었습니다. 1단계에서는 이미지 전반의 탄화된 절연체와 노출된 도체의 형태, 광택도를 객관적으로 식별하였습니다. 2단계에서는 식별된 질감을 스펀지형, 흑연화, 단순 용융, 단순 거칠기의 기준에 따라 대조 분석하였으며, 특히 다공성 구조의 깊이감 유무를 중점적으로 확인하였습니다. 3단계에서는 이러한 시각적 특징을 물리적 열화 기전과 연결하여, 기공 형성이 미미하고 표면이 불규칙하게 탄화된 상태임을 도출하였습니다. 분석 결과, 명확한 스펀지 현상이나 흑연화보다는 열에 의한 수지의 탄화 및 물리적 파손에 따른 '거친(Rough)' 질감이 지배적인 것으로 판단됩니다.\n\n### 최종 분석 결과 (JSON)\n\n```json"
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   },
#   "step3": {
#     "global_aging_detected": true,
#     "widespread_cracking": true,
#     "discoloration_pattern": "전선 전반에 걸쳐 피복의 흑색 탄화 및 불규칙한 탈색 패턴이 관찰됨",
#     "hardening_detected": true,
#     "brittleness_detected": true,
#     "localized_damage_only": false,
#     "confidence": 90,
#     "reasoning": "단락 지점뿐만 아니라 이미지 내에 노출된 전선 피복 전반에서 미세 균열과 경화 현상이 관찰됩니다. 이는 특정 지점의 기계적 손상이 아닌, 장기간에 걸친 열적 노후화로 인해 절연체 전체의 물성이 저하되었음을 시사합니다.",
#     "bboxes": [
#       [
#         305,
#         0,
#         405,
#         438
#       ],
#       [
#         540,
#         0,
#         630,
#         442
#       ],
#       [
#         365,
#         480,
#         415,
#         715
#       ],
#       [
#         300,
#         710,
#         595,
#         995
#       ]
#     ],
#     "thinking_process": {
#       "reasoning_text": "### 분석 과정 요약\n\n1.  **객관적 관찰 (Step 1):** 이미지 내 전선 피복의 전반적인 상태를 검토합니다. 피복의 표면에서 불규칙한 갈라짐(Cracking), 변색(Discoloration), 그리고 형태적 뒤틀림을 식별합니다. 특히 단락 지점뿐만 아니라 그와 인접하지 않은 원거리 영역까지 동일한 훼손 패턴이 나타나는지 확인합니다.\n2.  **논리적 해석 (Step 2):** 관찰된 균열과 변색이 특정 지점에 집중되지 않고 전선 전반에 걸쳐 분포하는 경우, 이는 열적·화학적 요인에 의한 고분자 재료의 광역적 노후화(Global Aging)로 해석됩니다. 피복의 유연성 상실로 인한 취성 파괴 양상을 분석하여 절연 성능 저하 가능성을 평가합니다.\n3.  **최종 판단 및 확신도 (Step 3):** 수집된 시각적 증거를 바탕으로 노후화의 광역성 여부를 결정합니다. 피복의 광범위한 탄화 및 균열이 확인될 경우 높은 확신도로 노후화를 진단하며, 화질이나 각도에 따른 불확실성을 고려하여 확신도를 산출합니다.\n4.  **대안적 가능성 (Step 4):** 광역적 노후화 외에 과전류에 의한 일시적 과열 또는 외부 환경 요인(화학물질 노출 등)에 의한 국소적 손상 가능성을 검토하여 분석의 객관성을 유지합니다.\n\n---\n\n### 최종 분석 결과 (JSON)\n\n```json"
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   }
# }

# %%
# 5. 분석 결과 시각화 (AI 검출 위치 표시)
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import io
import numpy as np

def draw_bounding_boxes(image_path, analysis_results):
    """
    분석 결과에 포함된 Bounding Box를 이미지 위에 표시합니다.
    """
    try:
        # 이미지 로드
        img = Image.open(image_path)
        original_width, original_height = img.size
        
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(img)
        ax.set_title("AI Detected Regions", fontsize=15)
        axis_off = True
        
        colors = {'step1': 'red', 'step2': 'orange', 'step3': 'blue', 'step4': 'green'}
        labels = {'step1': 'Step 1', 'step2': 'Step 2', 'step3': 'Step 3', 'step4': 'Step 4'}
        
        legend_patches = []
        
        # 각 단계별 결과 시각화
        for step_key, color in colors.items():
            step_result = analysis_results.get(step_key, {})
            bboxes = step_result.get('bboxes', [])
            
            if bboxes:
                axis_off = False
                legend_patches.append(patches.Patch(color=color, label=f"{labels[step_key]} ({len(bboxes)})"))
                
                for box in bboxes:
                    # 0-1000 정규화 좌표 -> 픽셀 좌표 변환
                    # box format: [ymin, xmin, ymax, xmax]
                    ymin, xmin, ymax, xmax = box
                    
                    x = xmin / 1000 * original_width
                    y = ymin / 1000 * original_height
                    w = (xmax - xmin) / 1000 * original_width
                    h = (ymax - ymin) / 1000 * original_height
                    
                    # 사각형 그리기
                    rect = patches.Rectangle((x, y), w, h, linewidth=2, edgecolor=color, facecolor='none')
                    ax.add_patch(rect)

        if legend_patches:
            ax.legend(handles=legend_patches, loc='upper right')
            
        plt.axis('off')
        plt.show()
        
        if not legend_patches:
            print("검출된 Bounding Box 정보가 없습니다.")
            
    except Exception as e:
        print(f"시각화 중 오류 발생: {e}")

# 시각화 함수 실행
if 'test_image_path' in locals() and 'result' in locals():
    # 결과에서 전문가 키 찾기 (동적)
    expert_results = result.get("expert_analysis_results", {})
    target_key = next(iter(expert_results), None) # 첫 번째 키 사용
    
    if target_key:
        print(f"Visualizing results for expert: {target_key}")
        analysis_results = expert_results[target_key]
        draw_bounding_boxes(test_image_path, analysis_results)
    else:
        print("분석 결과(expert_analysis_results)가 비어 있습니다.")
else:
    print("테스트 이미지 경로 또는 분석 결과가 없습니다.")
# Out:
# Visualizing results for expert: dielectric
