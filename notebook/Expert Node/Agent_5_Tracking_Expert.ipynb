# %% [markdown]
# # Agent 5: Tracking Expert (트래킹 전문가)

# %%
# Tracking Expert Graph Init
import sys
import os
from pathlib import Path
import json
import time

# 프로젝트 루트 경로 설정
project_root = Path.cwd().parent if Path.cwd().name == "notebook" else Path.cwd()
sys.path.insert(0, str(project_root))

# 환경 변수 로드
from dotenv import load_dotenv
load_dotenv(project_root / ".env")

print(f"✓ 프로젝트 루트: {project_root}")

# 2. 테스트 이미지 준비
from src.utils import find_data_directory
from src.tools.experts.expert_utils import save_bytes_to_temp_file
from src.tools.experts.expert_utils import call_gemini_text, parse_json_response

# Tracking Expert 관련 프롬프트
from src.prompts.tracking_expert_prompts import get_final_verdict_prompt

try:
    data_dir = find_data_directory()
    # 테스트할 이미지 파일명 (Tracking 분석에 적합한 이미지 권장)
    test_image_name = "Poor_Contact_001.jpg" 
    test_image_path = Path(data_dir) / test_image_name
    
    if not test_image_path.exists():
        image_files = list(Path(data_dir).glob("*.png")) + list(Path(data_dir).glob("*.jpg"))
        if image_files:
            test_image_path = image_files[0]
            print(f"⚠️ 지정된 이미지를 찾을 수 없어 {test_image_path.name}을 사용합니다.")
        else:
            raise FileNotFoundError("테스트할 이미지가 없습니다.")
            
    print(f"✓ 테스트 이미지: {test_image_path}")
    
    with open(test_image_path, 'rb') as f:
        image_data = f.read()
    temp_image_path = save_bytes_to_temp_file(image_data)
    print(f"✓ 임시 이미지 경로: {temp_image_path}")
    
except Exception as e:
    print(f"❌ 오류: {e}")

# 3. Hotspot 탐지 (메인 그래프와 동일한 방식, async → asyncio.run)
import asyncio
from src.nodes.common_nodes import hotspot_detector_node
from src.state import InvestigationState

print("✓ Hotspot 탐지 중...")
# hotspot_detector_node는 async이므로 asyncio.run으로 실행
temp_investigation_state = InvestigationState(
    payload=[],
    image_path=temp_image_path,
    hotspots=None,
    expert_reports=[],
    expert_analysis_results={},
    expert_confidence_scores={},
    expert_evidence={},
    final_verdict=None,
    errors=[]
)
hotspot_result = asyncio.run(hotspot_detector_node(temp_investigation_state))
detected_hotspots = hotspot_result.get("hotspots", [])
print(f"✓ 탐지된 Hotspots: {len(detected_hotspots)}개")

# 4. 그래프 빌드 및 상태 초기화 (실행 전 필수)
from src.graphs.tracking_expert_graph import build_tracking_expert_graph
from src.nodes.tracking_nodes import TrackingExpertState

print("✓ 그래프 빌드 및 초기 상태 생성 중...")

initial_state = TrackingExpertState(
    messages=[],
    image_path=temp_image_path,
    hotspots=detected_hotspots,  # 탐지된 hotspots 사용
    hotspot_queue=None,
    analysis_results=[],
    
    # Loop 변수 초기화
    current_hotspot=None,
    detector_result=None,
    roi_image_path=None,
    connection_type=None,
    
    # Tracking Specialist Results
    tracking_terminal_result=None,
    tracking_wire_result=None,
    tracking_plug_result=None,
    tracking_pcb_result=None,
    
    # Final Verdict
    verdict_report=None,
    verdict_confidence=None,
    verdict_result=None
)

graph = build_tracking_expert_graph()
print("✓ 완료: initial_state 및 graph 객체 준비됨")
# Out:
# ✓ 프로젝트 루트: c:\Users\user\Documents\Project\P_04_Scope
# ✓ 테스트 이미지: c:\Users\user\Documents\Project\P_04_Scope\data\Poor_Contact_001.jpg
# ✓ 임시 이미지 경로: C:\Users\user\AppData\Local\Temp\tmpdh89ne85.jpg
# ✓ Hotspot 탐지 중...
# 📂 [Hotspot Detector] 이미지 경로 감지: C:\Users\user\AppData\Local\Temp\tmpdh89ne85.jpg
#
# 📡 [Hotspot Detector] 다중 발화 지점 탐색 시작... (이미지: C:\Users\user\AppData\Local\Temp\tmpdh89ne85.jpg)
# 📋 [Hotspot Detector] Finish reason: FinishReason.STOP
#
# 💭 [Hotspot Detector] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정 (SDK Extracted)]:
# **Fire Scene Analysis: Objective Observations**
#
# Alright, let's break this down. As a world-class fire investigation expert, I need to analyze this image with absolute objectivity. My mind immediately begins sifting through the visual data, focusing on the key elements and adhering to strict protocols. First, I mentally run through the constraints: no causal inferences, only descriptive language focused on shape, color, location, size, and texture. I need to make sure I am outputting the information in a very specific JSON format.
#
# My initial scan reveals electrical wires and cables against a teal/green surface. I see a single-core wire, labeled as ①, and a multi-core cable assembly, ②, along with red markers numbered '3' and '5'. Now, I drill down into specifics.
#
# Wire ① on the left has blackened, partially missing insulation, exposing copper. The bottom segment of Wire ① is bare copper, exhibiting some discoloration. The multi-core cable ② on the right presents a thick grey outer sheath, with internal wires now exposed. The central area is the hot spot. There is significant charring and melting of the insulation. The exposed copper strands display green oxidation, or verdigris, and fused plastic/insulation is visible. Of particular interest is a bulbous, charred mass where multiple wires converge. Greenish-white residue is also present on some wire sections.
#
# Next, I establish the global context. The image features a multi-core power cable and individual branch wires. The critical pattern is localized, intense charring and melting occurring at the junction point. This damage distributes horizontally and radially. My internal heat flow model tells me the concentration of heat is at the junction of cable ② and wires ①, radiating outward, as evidenced by the decreasing charring intensity.
#
# Now, a detailed object description emerges: Cable ② is a grey PVC/rubber sheath, approximately 10-15mm in diameter. Its end is severely charred and frayed. Wire ① on the left has black insulation with a brittle texture, showing longitudinal cracking. The bottom segment of Wire ① reveals bare copper, with a reddish-brown to dull orange coloration. The critical Junction area is covered in black carbonized residue, forming an irregular shape. Greenish-blue oxidation is also present on exposed strands.
#
# I select hotspots based on these observations. Hotspot 1, centered on that charred mass and junction area, is a priority due to the maximum material loss, carbonization, and fusion of multiple conductors. Hotspot 2 is near the red marker '5', representing a transition point from intact insulation to a bare conductor with localized charring.
#
# Assessing image quality is the next mental step. The image has good lighting and clear contrast, which is positive. However, I note some motion blur or focus issues, particularly regarding the fine copper strands. The resolution is adequate for a general overview, but it lacks the micro-detail necessary for metallurgical analysis. I mentally add suggestions to recommend macro photography for the fused areas, and potentially sharpening filters to enhance the images.
#
# Finally, I mentally check the scene overview: focusing on the cable assembly and localized thermal damage, using terminology such as "carbonization," "thermal degradation," and "oxidation." The detailed observations include mentions of "verdigris," "charred residue," and "exposed core." My mental model focuses on two hotspots, the main charred junction (approximate coordinates [360, 700, 580, 950]) and the area near marker 5 ([250, 250, 380, 450]). I note the image's clarity while also recommending higher magnification for a more precise analysis of the fused sections.
#
# Before committing to the JSON output, I mentally verify the constraints: no causal language like "short circuit" or "arcing", and the format is JSON, it's objective, and the terms used are highly technical. Now, I'm ready to produce the report.
#
# 📄 [JSON 응답]:
# {
#   "scene_overview": "청록색 바닥재 위에 놓인 다심 케이블(②)과 분기된 단심 전선(①)들의 열화 및 소실 상태를 보여주는 이미지임. 케이블 접합부 및 분기점을 중심으로 국부적인 탄화(Carbonization)와 절연 피복의 용융(Melting)이 집중되어 있으며, 전선 말단부로 갈수록 열 피해 정도가 감소하는 방사형 연소 패턴이 관찰됨. 일부 동선 표면에는 녹색의 산화물(Verdigris)이 형성되어 있음.",
#   "detailed_observations": [
#     "케이블(②) 말단 및 분기 지점: 회색 외부 시스(Sheath)가 열에 의해 수축 및 탄화되었으며, 내부 절연체는 완전히 소실되어 다수의 동선(Copper wire) 소선들이 노출됨. 노출된 소선 뭉치 사이에는 검은색의 불규칙한 탄화 잔류물이 고착되어 있음.",
#     "전선(①) 좌측 구간: 검은색 절연 피복이 열에 의해 경화되고 길이 방향으로 균열이 발생함. 마커 '5' 부근에서는 피복이 소실되어 내부 동선이 노출되었으며, 노출된 동선은 어두운 갈색으로 변색됨.",
#     "전선(①) 하단 구간: 마커 '3'이 부착된 전선은 절연 피복이 거의 관찰되지 않는 나전선 상태이며, 표면은 광택을 잃은 둔탁한 주황색 및 갈색을 띰.",
#     "중앙 상단 전선 분기부: 동선 표면에 밝은 녹색 및 흰색의 분말 형태 부식 생성물이 관찰됨. 이는 수분 또는 화학적 반응에 의한 구리 산화물 형성으로 추정됨.",
#     "이미지 해상도 제약으로 인해 노출된 동선 소선 말단의 미세한 용융구(Melted bead) 형성 여부 및 표면의 미세 균열(Micro-crack) 상태를 확정하기 어려움."
#   ],
#   "hotspots": [
#     {
#       "id": 1,
#       "box_2d": [365, 715, 565, 915],
#       "reason_for_selection": "케이블(②)에서 전선들이 분기되는 지점으로, 이미지 내에서 가장 심한 탄화와 재질 변형이 관찰됨. 절
# ... (총 1801자)
# ------------------------------------------------------------
# ✅ [Hotspot Detector] 발견된 Hotspots: 2개
#    - ID 1: Localized Severe Carbonization & Material Fusion (국부적 심화 탄화 및 재질 융합) (Score: 92)
#    - ID 2: Copper Oxidation & Corrosion Product (구리 산화 및 부식 생성물 형성) (Score: 78)
# ✓ 탐지된 Hotspots: 2개
# ✓ 그래프 빌드 및 초기 상태 생성 중...
# ✓ 완료: initial_state 및 graph 객체 준비됨
# c:\Users\user\Documents\Project\P_04_Scope\venv\Lib\site-packages\torchvision\transforms\functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Tracking Expert Graph Run

from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import os

print("=" * 60)
print("Multi-Hotspot Loop 전체 실행 (Deform Specialist)")
print("=" * 60)

start_time = time.time()
try:
    # Recursion Limit을 넉넉히 주어야 Loop가 돕니다.
    final_state = graph.invoke(initial_state, config={"recursion_limit": 50})
    elapsed = time.time() - start_time
    
    print(f"\n✓ 전체 실행 완료 (소요시간: {elapsed:.2f}초)")
    
    # 분석된 결과들 가져오기
    analysis_results = final_state.get("analysis_results", [])
    
    # 한글 폰트 설정 (Windows)
    try:
        # Windows에서 사용 가능한 한글 폰트 찾기
        font_list = ['Malgun Gothic', 'NanumGothic', 'NanumBarunGothic', 'Gulim', 'Batang']
        font_found = None
        for font_name in font_list:
            try:
                font_path = fm.findfont(fm.FontProperties(family=font_name))
                if font_path:
                    plt.rcParams['font.family'] = font_name
                    font_found = font_name
                    break
            except:
                continue
        
        if font_found:
            print(f"✓ 한글 폰트 설정: {font_found}")
        else:
            # 폰트를 찾지 못한 경우 경고만 출력하고 계속 진행
            print("⚠️ 한글 폰트를 찾을 수 없습니다. 한글이 제대로 표시되지 않을 수 있습니다.")
    except Exception as e:
        print(f"⚠️ 폰트 설정 중 오류: {e}")
    
    if not analysis_results:
        print("No analyzed images found.")
    else:
        num_images = len(analysis_results)
        if num_images > 0:
            # 서브플롯 크기 및 배열 설정
            cols = min(num_images, 5)
            rows = (num_images - 1) // cols + 1
            fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
            
            # axes가 단일 객체이거나 1차원 배열일 경우 처리
            if num_images == 1:
                axes = [axes]
            elif rows > 1:
                axes = axes.flatten()
            
            # 빈 서브플롯 숨기기
            if hasattr(axes, '__len__') and len(axes) > num_images:
                for ax in axes[num_images:]:
                    ax.axis('off')
            
            for idx, res in enumerate(analysis_results):
                # Data Extraction optimized for Deform Expert
                h_info = res.get('hotspot_info', {})
                hotspot_id = h_info.get('id', '?')
                feature = h_info.get('damage_type', 'Unknown')
                conn_type = res.get('connection_type', 'N/A')
                
                roi_path = res.get('roi_image_path')
                
                # Specialist Result Extraction
                # Deform Expert도 'specialist_result' 필드를 사용
                spec_res = res.get('specialist_result', {}) or {}
                
                verdict = spec_res.get('verdict', 'Indeterminate')
                # 긴 Verdict 문자열 줄임 처리
                if len(verdict) > 20: 
                    verdict = verdict.split('(')[0].strip() # 괄호 앞부분만 사용
                    
                conf = spec_res.get('confidence', 0)
                
                ax = axes[idx]
                
                if roi_path and os.path.exists(roi_path):
                    try:
                        img = Image.open(roi_path)
                        ax.imshow(img)
                        # Title 구성: ID, 판정 결과, 신뢰도
                        title_text = f"ID {hotspot_id}: {feature}\n[{conn_type}]\n{verdict} ({conf}%)"
                            
                        # Deform Expert 판정에 따른 색상
                        # 압착(Compression), 절단(Cut), 내부폭발(Internal) 등의 키워드에 따라 색상 구분
                        if "Compression" in verdict or "Crushing" in verdict or "Cut" in verdict or "Imprint" in verdict:
                             title_color = 'red' # 명확한 기계적 변형
                        elif "Internal" in verdict or "Explosion" in verdict:
                             title_color = 'purple' # 내부 요인
                        elif "Thermal" in verdict or "Melt" in verdict:
                             title_color = 'orange' # 열변형
                        else:
                             title_color = 'blue'

                        ax.set_title(title_text, fontsize=10, color=title_color)
                    except Exception as e:
                        ax.text(0.5, 0.5, "Error Loading", ha='center')
                        print(f"Error loading image {roi_path}: {e}")
                else:
                    ax.text(0.5, 0.5, "Image Not Found", ha='center')
                    ax.set_title(f"ID {hotspot_id}")
                    
                ax.axis('off')
            
            plt.tight_layout()
            plt.show()

except Exception as e:
    print(f"❌ 실행 중 오류: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ============================================================
# Multi-Hotspot Loop 전체 실행 (Deform Specialist)
# ============================================================
#
# ⚖️ [Hotspot Manager] Hotspot 우선순위 정렬 및 Top-N 선별
# ✅ 선별된 Hotspots: [1, 2]
#
# ▶️ [Hotspot Manager] Processing Hotspot ID 1 (Localized Severe Carbonization & Material Fusion (국부적 심화 탄화 및 재질 융합))
# ✂️ [ROI Crop] Hotspot 영역 크롭... [365, 715, 565, 915]
# ✨ [Enhancement] ROI 이미지 2배 향상 적용 중...
# ✨ [Enhancement] 향상 완료: C:\Users\user\AppData\Local\Temp\roi_crop_v4zra6x9.jpg
#
# 🔍 [Component Classifier] 부품 유형 식별 중... (Dual Input: Context + Detail, ROI: C:\Users\user\AppData\Local\Temp\roi_crop_v4zra6x9.jpg)
# 👁️ [Observation] 회색의 굵은 케이블 외피에서 여러 가닥의 연선(Stranded wire)들이 뻗어 나와 있으며, 이들이 한데 모여 꼬여 있는(Twist) 형태가 관찰됨. 전선들이 모이는 지점에는 검게 탄화된 절연물 잔해가 뭉쳐 있음.
# ✅ 판별 결과: Splice (신뢰도: 85%)
# 📝 [Result Aggregator] ID 1 결과 기록 (Type: Splice, Verdict: Unknown)
#
# ▶️ [Hotspot Manager] Processing Hotspot ID 2 (Copper Oxidation & Corrosion Product (구리 산화 및 부식 생성물 형성))
# ✂️ [ROI Crop] Hotspot 영역 크롭... [165, 385, 335, 485]
# ✨ [Enhancement] ROI 이미지 2배 향상 적용 중...
# ✨ [Enhancement] 향상 완료: C:\Users\user\AppData\Local\Temp\roi_crop_3t7mzl2_.jpg
#
# 🔍 [Component Classifier] 부품 유형 식별 중... (Dual Input: Context + Detail, ROI: C:\Users\user\AppData\Local\Temp\roi_crop_3t7mzl2_.jpg)
# 👁️ [Observation] 여러 가닥의 구리 전선(도체)이 한 지점에서 서로 꼬여 있거나 뭉쳐져 연결된 형태가 관찰됨. 연결 부위에는 녹색 및 흰색의 부식물 또는 열에 의해 변형된 절연물 잔해가 부착되어 있으며, 전선들이 서로 얽혀 분기되는 구조를 보임.
# ✅ 판별 결과: Splice (신뢰도: 95%)
# 📝 [Result Aggregator] ID 2 결과 기록 (Type: Splice, Verdict: Unknown)
#
# 🏁 [Hotspot Manager] 모든 Hotspot 처리 완료.
# 📋 [Tracking Verdict] Finish reason: FinishReason.STOP
#
# 💭 [Tracking Verdict] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정 (SDK Extracted)]:
# **My Assessment of the Fire's Cause**
#
# Okay, I've got the report here, and my task is clear: determine if this fire was caused by "tracking." As the lead fire investigator, I need to methodically break this down. My process is always rooted in the evidence, and I'm looking for the hallmarks of tracking – those dendrites, the graphitization, that tell-tale carbonized path. I’m thinking in terms of "Cause" versus "Result"; simple charring is a result, while dendrites point to the cause.
#
# I’m seeing that this is structured around two key "Nodes" – a broad scanner and a specialist microscope. Crucially, the specialist’s findings hold more weight in my final verdict; this is smart, I always rely on that detailed analysis.
#
# The report presents two specific “Spot IDs.” For both, Node 0 (the initial scan) shows nothing specific. Node 2 (the microscope) indicates analysis was “impossible” or notes "no specific findings" linked to "Splice." A "Splice" is interesting, but without any positive evidence of electrical failure, it's just a point of interest.
#
# The JSON formatting is present and well-structured, which is great. It looks like the report adheres to a clear conclusion, probability, evidence, and reasoning sections.
#
# Here’s the rub, and it’s a big one. *There is absolutely no evidence of tracking in either spot*. No dendrites, no graphitization, no carbonized paths – nothing. The specialist’s findings are definitive: either “analysis impossible” or no specific evidence was found.
#
# My final conclusion: **Low** or **None** probability of tracking being the cause. In this case, with no evidence, None is appropriate. The key evidence against tracking is simple: a complete *absence* of any tracking-specific indicators from the detailed analysis. And the reasoning is straightforward: both spot IDs lack the required physical evidence and the specialist’s findings do not indicate any tracking. The expert findings say it's not present.
#
# The JSON is well formatted and this matches my own expert opinion. The conclusion is simple charring or external fire.
#
# 📄 [JSON 응답]:
# {
#   "conclusion": "단순 탄화 또는 외부 화재 (Low)",
#   "probability": "None",
#   "key_evidence": [
#     "전문가 정밀 분석(Node 2) 결과 특이사항 없음",
#     "트래킹의 고유 증거(수지상 패턴, 흑연화 도전로 등) 식별 불가"
#   ],
#   "reasoning": "제출된 보고서의 모든 조사 지점(Spot ID 1, 2)에서 트래킹 현상을 입증할 수 있는 어떠한 증거도 발견되지 않았습니다. 정밀 분석을 담당하는 Node 2(전문가)가 해당 부위에 대해 '분석 불가' 또는 '특이사항 없음'으로 결론을 내렸으며, 트래킹의 결정적 지표인 수지상 패턴, 흑연화, 또는 탄화 도전로에 대한 언급이 전혀 없습니다. 따라서 해당 부위는 화재의 원인이 아닌 단순 열해에 의한 탄화이거나 외부 화재에 의한 결과물일 가능성이 높으므로 트래킹 가능성은 없는 것으로 판정합니다."
# }
# ```
# ------------------------------------------------------------
#
# ✓ 전체 실행 완료 (소요시간: 37.26초)
# ✓ 한글 폰트 설정: Malgun Gothic
