# %% [markdown]
# # Agent 4: Partial Break Expert (반단선 전문가)
#
# 이 노트북은 **Partial Break Expert** 에이전트의 워크플로우를 테스트합니다.
# Agent 1 (Contact Expert)의 Multi-Hotspot Loop 구조를 기반으로 작성되었습니다.

# %%
# Partial Break Expert Graph Init
import sys
import os
from pathlib import Path
import json
import time

# 프로젝트 루트 경로 설정
project_root = Path.cwd().parent if Path.cwd().name == "notebook" else Path.cwd()
sys.path.insert(0, str(project_root))

# 환경 변수 로드
from dotenv import load_dotenv
load_dotenv(project_root / ".env")

print(f"✓ 프로젝트 루트: {project_root}")

# 2. 테스트 이미지 준비
from src.utils import find_data_directory
from src.tools.experts.expert_utils import save_bytes_to_temp_file
from src.tools.experts.expert_utils import call_gemini_text, parse_json_response

# Partial Break Expert 관련 프롬프트
from src.prompts.partial_break_expert_prompts import get_final_verdict_prompt

try:
    data_dir = find_data_directory()
    # 테스트할 이미지 파일명 (Partial Break 테스트에 적합한 이름 권장)
    test_image_name = "IMG_8113.jpg" 
    test_image_path = Path(data_dir) / test_image_name
    
    if not test_image_path.exists():
        # 파일이 없으면 data 디렉토리의 첫 번째 이미지 사용
        image_files = list(Path(data_dir).glob("*.png")) + list(Path(data_dir).glob("*.jpg"))
        if image_files:
            test_image_path = image_files[0]
            print(f"⚠️ 지정된 이미지를 찾을 수 없어 {test_image_path.name}을 사용합니다.")
        else:
            raise FileNotFoundError("테스트할 이미지가 없습니다.")
            
    print(f"✓ 테스트 이미지: {test_image_path}")
    
    with open(test_image_path, 'rb') as f:
        image_data = f.read()
    temp_image_path = save_bytes_to_temp_file(image_data)
    print(f"✓ 임시 이미지 경로: {temp_image_path}")
    
except Exception as e:
    print(f"❌ 오류: {e}")

# 3. 그래프 빌드 및 상태 초기화 (실행 전 필수)
from src.graphs.partial_break_expert_graph import build_partial_break_expert_graph
from src.nodes.partial_break_nodes import PartialBreakExpertState

print("✓ 그래프 빌드 및 초기 상태 생성 중...")

initial_state = PartialBreakExpertState(
    messages=[],
    image_path=temp_image_path,
    hotspots=[],
    hotspot_queue=None,
    analysis_results=[],
    
    # Loop 변수 초기화
    current_hotspot=None,
    detector_result=None,
    roi_image_path=None,
    
    # Classification & Specialist
    connection_type=None,
    is_wire=None,
    specialist_result=None,
    
    # Final Verdict
    verdict_report=None,
    verdict_confidence=None,
    verdict_result=None
)

graph = build_partial_break_expert_graph()
print("✓ 완료: initial_state 및 graph 객체 준비됨")
# Out:
# ✓ 프로젝트 루트: c:\Users\loidn\Documents\Projects\P_04_Scope
# ✓ 테스트 이미지: c:\Users\loidn\Documents\Projects\P_04_Scope\data\IMG_8113.jpg
# ✓ 임시 이미지 경로: C:\Users\loidn\AppData\Local\Temp\tmp8bshqib9.jpg
# ✓ 그래프 빌드 및 초기 상태 생성 중...
# ✓ 완료: initial_state 및 graph 객체 준비됨
# c:\Users\loidn\Documents\Projects\P_04_Scope\venv\Lib\site-packages\torchvision\transforms\functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
# Partial Break Expert Graph Run
try:
    print("=" * 60)
    print("Multi-Hotspot Loop 전체 실행 (Partial Break Expert)")
    print("=" * 60)

    start_time = time.time()
    
    # Recursion Limit을 넉넉히 설정 (Loop 회전 고려)
    final_state = graph.invoke(initial_state, config={"recursion_limit": 50})
    elapsed = time.time() - start_time
    
    print(f"\n✓ 전체 실행 완료 (소요시간: {elapsed:.2f}초)")
    
    # 1. 최종 리포트 출력
#     print("\n📊 최종 리포트 (Verdict):")
#     print("-" * 60)
#     print(final_state.get("verdict_report", "결과 없음"))
#     
    # 2. 발견된 Hotspots 확인
#     hotspots = final_state.get("hotspots", [])
#     print(f"\n🔍 발견된 Hotspots: {len(hotspots)}개")
#     for h in hotspots:
#         print(f"   - ID {h.get('id')}: {h.get('damage_type')} (Score: {h.get('severity_score', 0)})")
#     
    # 3. 상세 분석 결과 JSON 출력
#     print("\n📄 [Detailed Analysis Results]")
#     print("-" * 60)
#     analysis_results = final_state.get("analysis_results", [])
    # JSON 직렬화 불가 객체(이미지 등)가 있을 수 있으므로 safe print
#     print(json.dumps(analysis_results, indent=2, ensure_ascii=False, default=str))
# 
    # 4. 결과 시각화 (Processed Images & Results)
#     print("\n📷 [Processed Images Visualization]")
#     print("-" * 60)
#     
#      from PIL import Image
#      import matplotlib.pyplot as plt
#      import matplotlib.font_manager as fm
#      import os
#      
    # 한글 폰트 설정 (Windows)
#      try:
        # Windows에서 사용 가능한 한글 폰트 찾기
#          font_list = ['Malgun Gothic', 'NanumGothic', 'NanumBarunGothic', 'Gulim', 'Batang']
#          font_found = None
#          for font_name in font_list:
#              try:
#                  font_path = fm.findfont(fm.FontProperties(family=font_name))
#                  if font_path:
#                      plt.rcParams['font.family'] = font_name
#                      font_found = font_name
#                      break
#              except:
#                  continue
#          
#          if font_found:
#              print(f"✓ 한글 폰트 설정: {font_found}")
#          else:
            # 폰트를 찾지 못한 경우 경고만 출력하고 계속 진행
#              print("⚠️ 한글 폰트를 찾을 수 없습니다. 한글이 제대로 표시되지 않을 수 있습니다.")
#      except Exception as e:
#          print(f"⚠️ 폰트 설정 중 오류: {e}")
#      
#      if not analysis_results:
#          print("No analyzed images found.")
#      else:
#          num_images = len(analysis_results)
#          if num_images > 0:
            # 서브플롯 크기 및 배열 설정
#              cols = min(num_images, 5)
#              rows = (num_images - 1) // cols + 1
#              fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
#              
            # axes가 단일 객체이거나 1차원 배열일 경우 처리
#              if num_images == 1:
#                  axes = [axes]
#              elif rows > 1:
#                  axes = axes.flatten()
#              
            # 빈 서브플롯 숨기기
#              if hasattr(axes, '__len__') and len(axes) > num_images:
#                  for ax in axes[num_images:]:
#                      ax.axis('off')
#              
#              for idx, res in enumerate(analysis_results):
                # Data Extraction adapted for Partial Break structure
#                  h_info = res.get('hotspot_info', {})
#                  hotspot_id = h_info.get('id', '?')
#                  feature = h_info.get('damage_type', 'Unknown')
#                  
#                  roi_path = res.get('roi_image_path') # Fixed: use roi_image_path instead of roi_path
#                  spec_res = res.get('specialist_result', {}) or {}
#                  
#                  is_pb = spec_res.get('is_partial_break', False)
#                  conf = spec_res.get('confidence', 0)
#                  
#                  ax = axes[idx]
#                  
#                  if roi_path and os.path.exists(roi_path):
#                      try:
#                          img = Image.open(roi_path)
#                          ax.imshow(img)
                        # Title 구성: ID, 판정 결과, 신뢰도
#                          title_text = f"ID {hotspot_id}: {feature}\n"
#                          if is_pb:
#                              title_text += f"⚠️ Partial Break ({conf}%)"
#                          else:
#                              title_text += f"Normal / Other ({conf}%)"
#                              
#                          ax.set_title(title_text, fontsize=10, color='red' if is_pb else 'blue')
#                      except Exception as e:
#                          ax.text(0.5, 0.5, "Error Loading", ha='center')
#                          print(f"Error loading image {roi_path}: {e}")
#                  else:
#                      ax.text(0.5, 0.5, "Image Not Found", ha='center')
#                      ax.set_title(f"ID {hotspot_id}")
#                      
#                  ax.axis('off')
#              
#              plt.tight_layout()
#              plt.show()

except Exception as e:
    print(f"❌ 실행 중 오류: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ============================================================
# Multi-Hotspot Loop 전체 실행 (Partial Break Expert)
# ============================================================
#
# 📡 [Hotspot Detector] 다중 발화 지점 탐색 시작... (이미지: C:\Users\loidn\AppData\Local\Temp\tmp8bshqib9.jpg)
# 📋 [Hotspot Detector] Finish reason: FinishReason.STOP
#
# 💭 [Hotspot Detector] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정]:
# ```json
#
# 📄 [JSON 응답]:
# {
#   "scene_overview": "수거된 전선 및 커넥터 부품 잔해를 격자판 위에 배치하여 촬영한 이미지로, 전선 피복의 국부적 탄화와 도체(연선)의 노출 및 비산 형태가 관찰됨. 우측의 금속 및 수지 재질 커넥터 뭉치를 중심으로 좌측으로 연장된 전선들에서 열에 의한 피복 소실과 소선(Strand)의 변색이 확인되며, 전반적으로 수평 방향의 열 흐름과 물리적 인장력이 작용했을 가능성을 시사하는 형태적 특징이 나타남.",
#   "detailed_observations": [
#     "좌측 상단 전선 말단: 흑색 절연 피복이 급격하게 얇아지며 소실된 형태를 보이며, 노출된 도체 끝단은 불규칙하게 끊어진 형상임. 피복 표면은 탄화되어 무광의 거친 질감을 나타냄.",
#     "우측 하단 커넥터 및 전선 연결부: 금속성 황색 도금 부위와 흑색 합성수지 하우징이 결합된 형태로, 수지 부분은 열에 의해 용융 및 탄화되어 형태가 왜곡됨. 금속 표면 일부에는 회색의 산화 피막으로 추정되는 물질
# ... (총 1634자)
# ------------------------------------------------------------
# ✅ [Hotspot Detector] 발견된 Hotspots: 2개
#    - ID 1: Localized Insulation Carbonization & Conductor Exposure (국부적 절연 탄화 및 도체 노출) (Score: 50)
#    - ID 2: Thermal Deformation & Surface Oxidation (열 변형 및 표면 산화) (Score: 50)
#
# ⚖️ [Hotspot Manager] Hotspot 우선순위 정렬 및 Top-N 선별
# ✅ 선별된 Hotspots: [1, 2]
#
# ▶️ [Hotspot Manager] Processing Hotspot ID 1 (Localized Insulation Carbonization & Conductor Exposure (국부적 절연 탄화 및 도체 노출))
# ✂️ [ROI Crop] Hotspot 영역 크롭... [335, 385, 405, 465]
# ✨ [Enhancement] ROI 이미지 2배 향상 적용 중...
# ✨ [Enhancement] 향상 완료: C:\Users\loidn\AppData\Local\Temp\roi_crop_as876uyz.jpg
#
# 🔍 [Component Classifier] 부품 유형 식별 중... (Dual Input: Context + Detail, ROI: C:\Users\loidn\AppData\Local\Temp\roi_crop_as876uyz.jpg)
# 👁️ [Observation] 여러 가닥의 가느다란 구리색 금속선(심선)들이 다발 형태로 노출되어 있으며, 일부 구간에는 검게 탄화된 절연 피복의 잔해가 남아 있음. 전선의 끝단은 불규칙하게 끊어지거나 소선들이 흩어져 있는 상태임.
# ✅ 판별 결과: Wire (신뢰도: 95%)
#
# ⚡ [PartialBreak] Node 3: Wire Analysis (2 Images: Context + ROI)
# 📋 [PartialBreak Specialist Analysis] Finish reason: FinishReason.STOP
#
# 💭 [PartialBreak Specialist Analysis] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정]:
# ```json
#
# 📄 [JSON 응답]:
# {
#    "visual_observation": "전선 끝부분이 매끄러운 구형이 아니라, 피복의 탄화물과 구리 심선이 뒤엉켜 불규칙하고 거친 덩어리(Blob) 형태를 띠고 있습니다. 심선 가닥들이 개별적으로 보이지 않고 뭉쳐져 있으며 표면 광택이 없습니다.",
#    "comparison": {
#        "electrical_signs": "매끄러운 진구 형태의 Arc Bead가 관찰되지 않으며, 용융 부위와 정상 부위 사이의 경계가 불분명하고 지저분함.",
#        "thermal_signs": "불규칙한 덩어리(Globule) 형태가 뚜렷하며, 열에 의한 광범위한 변색과 심한 산화(Oxidation) 및 탄화 현상이 동반됨."
#    },
#    "verdict": "Thermal Melting (Fire Damage)",
#    "confidence": 90,
#    "reasoning": "확대 이미지 분석 결과, 전선 끝단의 용융흔이 전기적 아크 특유의 매끄러운 구슬 형태가
# ... (총 655자)
# ------------------------------------------------------------
#
# ▶️ [Hotspot Manager] Processing Hotspot ID 2 (Thermal Deformation & Surface Oxidation (열 변형 및 표면 산화))
# ✂️ [ROI Crop] Hotspot 영역 크롭... [445, 695, 585, 835]
# ✨ [Enhancement] ROI 이미지 2배 향상 적용 중...
# ✨ [Enhancement] 향상 완료: C:\Users\loidn\AppData\Local\Temp\roi_crop_psydwoo0.jpg
#
# 🔍 [Component Classifier] 부품 유형 식별 중... (Dual Input: Context + Detail, ROI: C:\Users\loidn\AppData\Local\Temp\roi_crop_psydwoo0.jpg)
# 👁️ [Observation] 여러 가닥의 가는 구리색 금속선(연선)들이 뭉쳐 있거나 사방으로 흩어져 있는 형태가 관찰됨. 이 금속선들은 검게 탄화된 원통형 피복 또는 보호 슬리브 내부로 연결되어 있으며, 일부 구간에서는 외피가 소실되어 내부 도체가 길게 노출되어 있음.
# ✅ 판별 결과: Wire (신뢰도: 95%)
#
# ⚡ [PartialBreak] Node 3: Wire Analysis (2 Images: Context + ROI)
# 📋 [PartialBreak Specialist Analysis] Finish reason: FinishReason.STOP
#
# 💭 [PartialBreak Specialist Analysis] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정]:
# ```json
#
# 📄 [JSON 응답]:
# {
#    "visual_observation": "구리 심선(Strands)이 한곳으로 뭉치지 않고 여러 가닥으로 가늘게 갈라져 있으며, 끝부분이 불규칙하게 끊어진 형태입니다. 일부 심선은 끝으로 갈수록 가늘어지는 연신(Necking) 현상이 관찰되며, 전반적으로 검게 산화되어 광택이 없습니다.",
#    "comparison": {
#        "electrical_signs": "특유의 매끄럽고 광택이 있는 구형의 용융흔(Arc Bead)이 관찰되지 않으며, 용융부와 비용융부 사이의 뚜렷한 경계선이 부족함.",
#        "thermal_signs": "심선들이 열에 의해 연화된 상태에서 물리적 힘을 받아 끊어진 듯한 '엿가락' 형태의 단면과 불규칙한 덩어리 형태가 혼재함."
#    },
#    "verdict": "Thermal Melting (Fire Damage) / Mechanical Break",
#    "confidence": 85,
#    "reasoning": "전선 끝단
# ... (총 680자)
# ------------------------------------------------------------
#
# 🏁 [Hotspot Manager] 모든 Hotspot 처리 완료.
# --- [PartialBreak] Node 4: Final Verdict ---
# 📋 [PartialBreak Final Verdict] Finish reason: FinishReason.STOP
#
# 💭 [PartialBreak Final Verdict] 모델 응답 텍스트:
# ------------------------------------------------------------
# 📝 [Thinking 과정]:
# ```json
#
# 📄 [JSON 응답]:
# {
#   "conclusion": "단순 열해 또는 기계적 절단 (Low)",
#   "probability": "Low",
#   "key_evidence": [
#     "Node 2가 식별한 전기적 아크 증거(Arc Bead)의 부재",
#     "불규칙한 용융 덩어리 및 피복 탄화와의 일체화",
#     "열해로 약해진 상태에서의 물리적 인장 파괴(Frayed/Necking) 흔적"
#   ],
#   "reasoning": "수석 조사관으로서 Spot 1과 Spot 2의 증거를 종합 분석한 결과, 화재의 원인인 '반단선'으로 볼 수 있는 전기적 특이점이 발견되지 않았습니다. Node 2의 정밀 분석에 따르면, Spot 1은 전기적 아크 특유의 매끄러운 구슬 형태가 아닌 외부 열에 의한 '불규칙한 용융 덩어리'를 보이며, Spot 2 역시 아크 비드가 없고 열해에 의한 2차적 인장 파괴 형상이 뚜렷합니다. 이는 모두 화재의 '원인'이 아니라 화재 발생 후 외부 화염에 노출되어 나타나는 전형적인 '
# ... (총 547자)
# ------------------------------------------------------------
#
# ✓ 전체 실행 완료 (소요시간: 74.92초)
#
# 📊 최종 리포트 (Verdict):
# ------------------------------------------------------------
# [Partial Break 전문가 최종 판정]
# ## 결론: 단순 열해 또는 기계적 절단 (Low) (Low)
#
# ## 핵심 증거
# - Node 2가 식별한 전기적 아크 증거(Arc Bead)의 부재
# - 불규칙한 용융 덩어리 및 피복 탄화와의 일체화
# - 열해로 약해진 상태에서의 물리적 인장 파괴(Frayed/Necking) 흔적
#
# ## 종합 소견
# 수석 조사관으로서 Spot 1과 Spot 2의 증거를 종합 분석한 결과, 화재의 원인인 '반단선'으로 볼 수 있는 전기적 특이점이 발견되지 않았습니다. Node 2의 정밀 분석에 따르면, Spot 1은 전기적 아크 특유의 매끄러운 구슬 형태가 아닌 외부 열에 의한 '불규칙한 용융 덩어리'를 보이며, Spot 2 역시 아크 비드가 없고 열해에 의한 2차적 인장 파괴 형상이 뚜렷합니다. 이는 모두 화재의 '원인'이 아니라 화재 발생 후 외부 화염에 노출되어 나타나는 전형적인 '결과(열해)'이므로, 반단선 가능성은 매우 낮음(Low)으로 판정합니다.
#
# 🔍 발견된 Hotspots: 2개
#    - ID 1: Localized Insulation Carbonization & Conductor Exposure (국부적 절연 탄화 및 도체 노출) (Score: 50)
#    - ID 2: Thermal Deformation & Surface Oxidation (열 변형 및 표면 산화) (Score: 50)
#
# 📄 [Detailed Analysis Results]
# ------------------------------------------------------------
# [
#   {
#     "hotspot_id": 1,
#     "hotspot_info": {
#       "id": 1,
#       "box_2d": [
#         335,
#         385,
#         405,
#         465
#       ],
#       "reason_for_selection": "전선 피복이 끝단으로 갈수록 급격히 탄화되며 소실되는 양상을 보임. 피복의 탄화 경계면과 노출된 도체의 단면 형태를 통해 열의 집중도와 물리적 파손 시점을 분석할 가치가 있음.",
#       "suspected_feature": "Localized Insulation Carbonization & Conductor Exposure (국부적 절연 탄화 및 도체 노출)",
#       "damage_type": "Localized Insulation Carbonization & Conductor Exposure (국부적 절연 탄화 및 도체 노출)",
#       "severity_score": 50
#     },
#     "connection_type": "Wire",
#     "specialist_result": {
#       "visual_observation": "전선 끝부분이 매끄러운 구형이 아니라, 피복의 탄화물과 구리 심선이 뒤엉켜 불규칙하고 거친 덩어리(Blob) 형태를 띠고 있습니다. 심선 가닥들이 개별적으로 보이지 않고 뭉쳐져 있으며 표면 광택이 없습니다.",
#       "comparison": {
#         "electrical_signs": "매끄러운 진구 형태의 Arc Bead가 관찰되지 않으며, 용융 부위와 정상 부위 사이의 경계가 불분명하고 지저분함.",
#         "thermal_signs": "불규칙한 덩어리(Globule) 형태가 뚜렷하며, 열에 의한 광범위한 변색과 심한 산화(Oxidation) 및 탄화 현상이 동반됨."
#       },
#       "verdict": "Thermal Melting (Fire Damage)",
#       "confidence": 90,
#       "reasoning": "확대 이미지 분석 결과, 전선 끝단의 용융흔이 전기적 아크 특유의 매끄러운 구슬 형태가 아닌, 외부 열에 의해 서서히 녹아내린 불규칙한 덩어리 형태를 보입니다. 용융 부위가 넓고 피복의 탄화 흔적과 일체화되어 있는 점으로 보아, 이는 전기적 단락에 의한 화재 원인이기보다는 외부 화염에 노출되어 발생한 '열해(Thermal Damage)'로 판단됩니다."
#     },
#     "roi_image_path": "C:\\Users\\loidn\\AppData\\Local\\Temp\\roi_crop_as876uyz.jpg"
#   },
#   {
#     "hotspot_id": 2,
#     "hotspot_info": {
#       "id": 2,
#       "box_2d": [
#         445,
#         695,
#         585,
#         835
#       ],
#       "reason_for_selection": "금속 단자와 수지 하우징이 만나는 지점으로, 수지의 용융 변형과 금속 표면의 변색이 집중되어 있음. 재질 간의 열팽창 계수 차이에 의한 변형 및 표면 산화물 분석을 통해 해당 지점의 수열 온도를 추정할 필요가 있음.",
#       "suspected_feature": "Thermal Deformation & Surface Oxidation (열 변형 및 표면 산화)",
#       "damage_type": "Thermal Deformation & Surface Oxidation (열 변형 및 표면 산화)",
#       "severity_score": 50
#     },
#     "connection_type": "Wire",
#     "specialist_result": {
#       "visual_observation": "구리 심선(Strands)이 한곳으로 뭉치지 않고 여러 가닥으로 가늘게 갈라져 있으며, 끝부분이 불규칙하게 끊어진 형태입니다. 일부 심선은 끝으로 갈수록 가늘어지는 연신(Necking) 현상이 관찰되며, 전반적으로 검게 산화되어 광택이 없습니다.",
#       "comparison": {
#         "electrical_signs": "특유의 매끄럽고 광택이 있는 구형의 용융흔(Arc Bead)이 관찰되지 않으며, 용융부와 비용융부 사이의 뚜렷한 경계선이 부족함.",
#         "thermal_signs": "심선들이 열에 의해 연화된 상태에서 물리적 힘을 받아 끊어진 듯한 '엿가락' 형태의 단면과 불규칙한 덩어리 형태가 혼재함."
#       },
#       "verdict": "Thermal Melting (Fire Damage) / Mechanical Break",
#       "confidence": 85,
#       "reasoning": "전선 끝단에 전기적 단락의 증거인 '매끄러운 구슬(Arc Bead)'이 형성되지 않았습니다. 대신 심선들이 가늘게 늘어지며 끊어진 형태(Frayed/Necking)와 표면의 심한 산화 상태로 보아, 외부 화염에 의한 열해로 전선이 약해진 상태에서 물리적인 인장력에 의해 단선된 '2차적 화재 피해' 형상으로 판단됩니다."
#     },
#     "roi_image_path": "C:\\Users\\loidn\\AppData\\Local\\Temp\\roi_crop_psydwoo0.jpg"
#   }
# ]
#
# 📷 [Processed Images Visualization]
# ------------------------------------------------------------
# ✓ 한글 폰트 설정: Malgun Gothic
