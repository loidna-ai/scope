# %% [markdown]
# # Agent 4 Strand Fracture Expert 워크플로우 테스트
#
# 이 노트북은 `Strand Fracture Expert` (반단선 전문가)의 독립적인 워크플로우를 테스트합니다.
#
# ## 주요 기능
# - 테스트 이미지 로드
# - Strand Fracture Expert 그래프 실행 (Step 1 -> Step 2 -> Step 3)
# - 결과 분석 및 리포트 출력

# %%
# 1. 초기 설정 및 라이브러리 임포트
import sys
import os
from pathlib import Path
import json
import base64

# 프로젝트 루트 경로 설정
project_root = Path.cwd().parent if Path.cwd().name == "notebook" else Path.cwd()
sys.path.insert(0, str(project_root))

# 환경 변수 로드
from dotenv import load_dotenv
load_dotenv(project_root / ".env")

print(f"✓ 프로젝트 루트: {project_root}")
# Out:
# ✓ 프로젝트 루트: c:\Users\loidn\Documents\Projects\P_04_Scope

# %%
# 2. 테스트 이미지 준비
from src.utils import find_data_directory

try:
    data_dir = find_data_directory()
    test_image_name = "IMG_8113.jpg"
    test_image_path = Path(data_dir) / test_image_name
    
    if not test_image_path.exists():
        # 이미지가 없으면 첫 번째 가능한 이미지 사용
        image_files = list(Path(data_dir).glob("*.png")) + list(Path(data_dir).glob("*.jpg"))
        if image_files:
            test_image_path = image_files[0]
            print(f"⚠️ {test_image_name}을 찾을 수 없어 {test_image_path.name}을 사용합니다.")
        else:
            raise FileNotFoundError("테스트할 이미지가 없습니다.")
            
    print(f"✓ 테스트 이미지: {test_image_path}")
except Exception as e:
    print(f"❌ 오류: {e}")
# Out:
# ✓ 테스트 이미지: c:\Users\loidn\Documents\Projects\P_04_Scope\data\IMG_8113.jpg

# %%
# 3. Payload 생성 함수
def create_payload(image_path):
    with open(image_path, 'rb') as f:
        image_data = f.read()
    
    ext = Path(image_path).suffix.lower()
    mime_type = 'image/png' if ext == '.png' else 'image/jpeg'
    image_base64 = base64.b64encode(image_data).decode('utf-8')
    
    return [
        {"text": "이미지를 분석하세요."},
        {"inline_data": {"mime_type": mime_type, "data": image_base64}}
    ]

# %%
# 4. Strand Fracture Expert 실행
from src.graphs.strand_fracture_expert_graph import strand_fracture_expert_wrapper_node
from src.state import InvestigationState

print("Strand Fracture Expert 분석 시작...")

payload = create_payload(test_image_path)

# InvestigationState 모의 구성
mock_state = InvestigationState(
    payload=payload,
    expert_reports=[],
    expert_analysis_results={},
    expert_confidence_scores={},
    expert_evidence={},
    final_verdict=None,
    errors=[],
    strand_fracture_cached_image_data=None
)

try:
    result = strand_fracture_expert_wrapper_node(mock_state)
    
    print("\n✓ 분석 완료!")
    print("=" * 60)
    
    # 결과 출력
    reports = result.get("expert_reports", [])
    if reports:
        print(reports[0])
    else:
        print("리포트가 생성되지 않았습니다.")
        
    print("=" * 60)
    print("세부 분석 결과:")
    analysis_results = result.get("expert_analysis_results", {}).get("strand_fracture", {})
    print(json.dumps(analysis_results, indent=2, ensure_ascii=False))
    
except Exception as e:
    print(f"❌ 실행 중 오류 발생: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Strand Fracture Expert 분석 시작...
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: crop_image (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: 이미지 크롭 완료
# - 원본 크기: 1568x1176
# - 크롭된 크기: 1568x1176
# 🛠️ [Tool Call]: enhance_image (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: 이미지가 이미 선명하여 향상 작업을 건너뜁니다 (Variance: 417.8).
# - 원본 크기: 1568x1176
# 🛠️ [Tool Call]: analyze_tip_morphology_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: {"individual_strands_detected": true, "tapered_tips_detected": false, "micro_bead_at_tip": false, "thermal_discoloration": true, "necking_phenomenon": false, "tip_morphology": "unknown", "strand_separation": true, "necking_description": "이미지 해상도 및 배율 부족으로 인해 소선 끝단의 네킹, 미세 용융, 상세 열변색 패턴을 식별할 수 없음.", ...
#
# 🧠 [Thought]:
# Final Answer: 제공된 이미지를 분석한 결과, 소선의 끝단 형상 및 네킹 현상에 대한 상세 식별이 불가능합니다. 주요 분석 내용은 다음과 같습니다.
#
# 1.  **식별된 특징**: 개별 소선의 분리 상태와 열변색(Thermal Discoloration) 현상은 관찰되었습니다.
# 2.  **식별 불가능 항목**: 소선 끝단의 뾰족함(Tapered tips), 미세 용융 망울(Micro-bead), 그리고 네킹(Necking) 현상은 확인되지 않았습니다.
# 3.  **원인**: 해당 이미지는 전선 전체를 포함하는 광각 사진으로, 개별 소선 끝단의 미세한 형상을 분석하기에는 해상도와 배율이 부족합니다.
# 4.  **결론**: 시각적 증거 부족으로 인해 반단선 여부를 판단하기 위한 형태학적 분석이 불가능하며, 분석 신뢰도는 약 20%로 매우 낮습니다. 정확한 분석을 위해서는 소선 끝단 부위의 고배율 근접 촬영 사진이 필요합니다.
#
# ============================================================================
#
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: crop_image (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: 이미지 크롭 완료
# - 원본 크기: 1568x1176
# - 크롭된 크기: 1568x1176
# 🛠️ [Tool Call]: analyze_bead_distribution_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: {"micro_beads_detected": true, "bead_size": "micro", "bead_distribution": "individual_strands", "bead_count": "many", "bead_description": "다수의 소선 끝단에서 좁쌀 형태의 미세한 구형 용융흔이 관찰됨. 소선들이 하나로 뭉치지 않고 개별적인 용융 형태를 유지하고 있음.", "large_bead_present": false, "confidence": 85, "reasoning": "거대 망울 없이 개별 소선 끝단에 국부적인 미...
#
# 🧠 [Thought]:
# Final Answer: 이미지 분석 결과, 해당 전선에서는 다음과 같은 용융망울의 특징이 관찰되었습니다.
#
# 1. **용융망울 크기 및 형태**:
#    - 거대한 용융망울(Bead) 대신, 다수의 소선(Strand) 끝단에서 **좁쌀 형태의 미세한 구형 용융흔(Micro-beads)**이 관찰됩니다.
#    - 소선들이 하나로 크게 뭉치지 않고 개별적인 형태를 유지하고 있는 것이 특징입니다.
#
# 2. **분포 특성**:
#    - 용융흔이 특정 지점에 집중되지 않고 **개별 소선의 끝단마다 독립적으로 분포**하고 있습니다.
#    - 소선 단부와 피복 인접 부위에서 검은색 탄화물 및 변색이 동반되어 나타납니다.
#
# 3. **분석 결론**:
#    - **판단**: 대전류에 의한 전체 용융보다는 **반단선(Semi-disconnection)** 과정에서 발생하는 국부적인 미세 아크에 의한 형성 가능성이 매우 높습니다.
#    - **확신도**: 85% (형태학적 특징이 반단선 아크의 전형적인 패턴과 일치함)
#
# 이러한 미세 망울의 분포는 일반적인 단락흔(Short circuit bead)과는 구별되는 특징으로, 전선의 국부적 발열이나 미세 아크가 발생했음을 시사합니다.
#
# ============================================================================
#
#
# ==================== Agent Reasoning & Tool Execution ====================
# 🛠️ [Tool Call]: analyze_mechanical_fatigue_internal (Args: {'image_path': 'C:\\Users\\loidn\\AppData\\Local\\Temp\\tmp799ssix6.jpg'})
#    └─ 📊 [Tool Output]: {"mechanical_fatigue_detected": true, "fatigue_location": "strain_relief", "insulation_damage": true, "insulation_damage_type": "deformation", "bending_evidence": true, "location_match": true, "fatigue_description": "커넥터 연결 부위(스트레인 릴리프)에서 피복의 열적 변형과 함께 내부 소선들이 불규칙하게 흩어지고 끊어진 흔적이 관찰됨. 이는 반복적인 굽힘 스트레스...
#
# 🧠 [Thought]:
# Final Answer: 이미지 분석 결과, 해당 전선에서 **기계적 피로 흔적이 감지되었습니다.** 분석 내용은 다음과 같습니다.
#
# 1.  **감지 결과 및 위치**: 커넥터 연결 부위인 **스트레인 릴리프(Strain Relief)** 지점에서 기계적 피로가 확인되었습니다. 이 부위는 평소 반복적인 굽힘 스트레스가 집중되는 곳입니다.
# 2.  **주요 관찰 사항**:
#     *   **피복 손상**: 전선 피복 말단에서 열에 의한 변형과 탄화(검게 타는 현상) 흔적이 뚜렷하게 관찰됩니다.
#     *   **소선 상태**: 내부 구리 소선들이 불규칙하게 흩어져 있으며, 일부 소선은 끊어지거나 굽어 있는 상태입니다. 이는 외부 인장력이나 반복적인 굴곡에 의한 전형적인 피로 현상입니다.
# 3.  **원인 분석 (추론)**: 반복적인 굽힘으로 인해 소선이 일부 단선(반단선)되면서 해당 부위의 저항이 증가하였고, 이로 인해 발생한 열이 피복을 변형시킨 것으로 판단됩니다. 즉, **기계적 피로와 전기적 열손상이 복합적으로 작용**한 결과입니다.
# 4.  **분석 신뢰도**: **75%** (열적 손상이 심해 미세한 파단면 확인에는 한계가 있으나, 소선 이탈 양상이 기계적 피로의 특징을 강하게 나타냄)
#
# 결론적으로, 이 손상은 지속적인 물리적 스트레스가 누적되어 발생한 기계적 피로 파손으로 보입니다.
#
# ============================================================================
#
#
# ✓ 분석 완료!
# ============================================================
# [StrandFracture 전문가 리포트]
# ## 반단선 (Semi-disconnection) 판별 전문가 리포트
#
# **전문가:** 반단선 분석 전문가
#
# **분석 결과 요약:**
# 반단선 판정 신뢰도: 81%
#
# **단계별 분석 결과:**
#
# **1. 소선 끝단의 형상 분석:**
# - 개별 소선 확인: ✓ 확인됨
# - 뾰족한 끝단: ✗ 미탐지
# - 네킹 현상: ✗ 미확인
# - 끝단 형태: unknown
# - 신뢰도: 20%
#
# **2. 용융망울의 크기와 분포 분석:**
# - 미세 망울 탐지: ✓ 탐지됨
# - 망울 크기: micro
# - 망울 분포: individual_strands
# - 거대 망울 존재: ✗ 없음
# - 신뢰도: 85%
#
# **3. 기계적 피로 흔적 분석:**
# - 기계적 피로 탐지: ✓ 탐지됨
# - 피로 위치: strain_relief
# - 피복 손상: ✓ 확인됨
# - 위치 일치: ✓ 일치
# - 신뢰도: 75%
#
# **증거:**
# - Step 1: 개별 소선 확인 - 이미지 해상도 및 배율 부족으로 인해 소선 끝단의 네킹, 미세 용융, 상세 열변색 패턴을 식별할 수 없음.
# - Step 2: 미세 망울 확인 - 다수의 소선 끝단에서 좁쌀 형태의 미세한 구형 용융흔이 관찰됨. 소선들이 하나로 뭉치지 않고 개별적인 용융 형태를 유지하고 있음.
# - Step 3: 기계적 피로 확인 - 커넥터 연결 부위(스트레인 릴리프)에서 피복의 열적 변형과 함께 내부 소선들이 불규칙하게 흩어지고 끊어진 흔적이 관찰됨. 이는 반복적인 굽힘 스트레스가 가해지는 부위와 일치함.
#
# **결론:**
# 제공된 데이터를 기반으로 분석한 결과, 반단선에 의한 단락 가능성이 매우 높습니다 (신뢰도: 81%).
# ============================================================
# 세부 분석 결과:
# {
#   "step1": {
#     "individual_strands_detected": true,
#     "tapered_tips_detected": false,
#     "micro_bead_at_tip": false,
#     "thermal_discoloration": true,
#     "necking_phenomenon": false,
#     "tip_morphology": "unknown",
#     "strand_separation": true,
#     "necking_description": "이미지 해상도 및 배율 부족으로 인해 소선 끝단의 네킹, 미세 용융, 상세 열변색 패턴을 식별할 수 없음.",
#     "confidence": 20,
#     "reasoning": "광각 사진으로 인해 개별 소선 끝단의 미세 형상(네킹 등) 분석이 불가함. 시각적 증거 부족으로 판단 보류.",
#     "thinking_process": {
#       "reasoning_text": "분석 과정 요약:\n제공된 이미지는 전선 전체를 포함하는 광각 사진(Macro shot)으로, 개별 소선 끝단의 미세한 형상을 관찰하기에는 배율과 해상도가 부족합니다. 따라서 소선 끝단의 뾰족함, 미세 용융 망울, 그리고 고배율에서만 식별 가능한 네킹(Necking) 현상을 확정할 수 없습니다. 시각적 정보의 제한으로 인해 반단선 여부를 판단하기 위한 형태학적 특징 분석이 불가능하므로 보수적인 관점에서 판단을 보류합니다."
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   },
#   "step2": {
#     "micro_beads_detected": true,
#     "bead_size": "micro",
#     "bead_distribution": "individual_strands",
#     "bead_count": "many",
#     "bead_description": "다수의 소선 끝단에서 좁쌀 형태의 미세한 구형 용융흔이 관찰됨. 소선들이 하나로 뭉치지 않고 개별적인 용융 형태를 유지하고 있음.",
#     "large_bead_present": false,
#     "confidence": 85,
#     "reasoning": "거대 망울 없이 개별 소선 끝단에 국부적인 미세 망울이 형성된 점은 반단선 아크의 전형적 형태학적 특징과 일치함.",
#     "thinking_process": {
#       "reasoning_text": "금속 재료 공학 및 화재 감식 전문가로서, 제공된 이미지를 바탕으로 전선 용융흔의 형태학적 분석을 수행합니다.\n\n### [분석 프로세스 요약]\n\n**1. 객관적 관찰 (Observations)**\n- **형태:** 다수의 연동선(Strand)이 흐트러진 형태로 분포하며, 일부 소선 끝단에 미세한 구형 또는 반구형의 융기부가 관찰됩니다.\n- **색상 및 질감:** 소선은 전반적으로 구리색을 띠고 있으나, 단부와 피복 인접 부위에서 검은색 탄화물 및 변색이 확인됩니다.\n- **배치:** 거대한 일체형 용융망울(Primary/Secondary Arc Bead)은 보이지 않으며, 소선 각각의 끝단이 개별적으로 변형된 양상을 보입니다.\n\n**2. 논리적 해석 (Interpretation)**\n- **에너지 국부성:** 대전류에 의한 전체 용융이 아닌, 국부적인 발열 또는 미세 아크에 의해 개별 소선이 용융된 것으로 보입니다. 이는 반단선(Semi-disconnection) 과정에서 발생하는 국부적 아크의 전형적인 특징과 유사합니다.\n- **비교 분석:** 일반적인 단락흔(Short circuit bead)은 여러 소선이 뭉쳐 하나의 큰 구체를 형성하나, 현재 이미지는 소선의 개별성이 유지된 채 끝단만 미세하게 용융된 '미세 망울(Micro-beads)' 패턴을 보입니다.\n\n**3. 최종 판단 및 확신도 (Conclusion & Confidence)**\n- **결론:** 개별 소선 끝단에 형성된 미세 망울의 존재와 분포로 볼 때, 반단선에 의한 국부적 아크 발생 가능성이 높습니다.\n- **확신도:** 85% (육안상 미세 망울이 관찰되나, 정밀한 현미경 확대 이미지가 아니므로 표면의 미세 기공이나 용융 경계면을 확정하기에는 제약이 있음)\n\n**4. 대안적 가능성 (Alternative Hypotheses)**\n- **단순 기계적 단선 및 화열 수열:** 아크에 의한 용융이 아닌, 외부 화염에 의한 고온 노출로 인해 소선 끝단이 열변형을 일으켰을 가능성을 배제할 수 없습니다.\n\n---"
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   },
#   "step3": {
#     "mechanical_fatigue_detected": true,
#     "fatigue_location": "strain_relief",
#     "insulation_damage": true,
#     "insulation_damage_type": "deformation",
#     "bending_evidence": true,
#     "location_match": true,
#     "fatigue_description": "커넥터 연결 부위(스트레인 릴리프)에서 피복의 열적 변형과 함께 내부 소선들이 불규칙하게 흩어지고 끊어진 흔적이 관찰됨. 이는 반복적인 굽힘 스트레스가 가해지는 부위와 일치함.",
#     "confidence": 75,
#     "reasoning": "반복적 굴곡이 발생하는 지점에서 소선의 이탈과 피복 손상이 집중되어 있으나, 탄화 흔적이 강하게 남아 있어 기계적 피로와 전기적 열손상이 복합적으로 작용한 것으로 판단됨.",
#     "thinking_process": {
#       "reasoning_text": "### 분석 과정 요약\n\n**Step 1. 객관적 관찰 (Observations)**\n- 전선 피복의 말단 부위에서 열에 의한 변형 및 탄화 흔적이 관찰됩니다.\n- 내부 구리 소선들이 여러 가닥으로 분리되어 흩어져 있으며, 일부 소선은 끊어지거나 굴곡진 형태를 보입니다.\n- 오른쪽 커넥터 결합부 부근의 피복은 검게 변색되어 있으며, 물리적인 마모보다는 열적 손상의 특징이 더 강하게 나타납니다.\n\n**Step 2. 논리적 해석 (Interpretation)**\n- 소선들의 불규칙한 분산과 굴곡은 외부 인장력이나 반복적인 굽힘에 의한 기계적 피로의 결과일 수 있습니다.\n- 그러나 피복의 탄화 상태와 소선 말단의 변색은 전기적 과부하 또는 단락(Short circuit)으로 인한 열적 스트레스가 동반되었음을 시사합니다.\n- 기계적 피로로 인해 소선이 일부 단선(반단선)된 상태에서 저항이 증가하여 발열이 발생했을 가능성이 논리적으로 연결됩니다.\n\n**Step 3. 최종 판단 및 확신도 (Conclusion & Confidence)**\n- 기계적 피로와 열적 손상이 혼재되어 나타나며, 특히 스트레인 릴리프 부근에서의 소선 이탈이 뚜렷합니다.\n- 확신도: 75%. (열적 손상이 심하여 순수한 기계적 피로 파단면의 미세 구조를 확인하기에는 해상도와 시각적 정보가 제한적임)\n\n**Step 4. 대안적 가능성 (Alternative Hypotheses)**\n- 기계적 피로가 아닌, 순간적인 강한 외부 인장력에 의한 물리적 파손 및 그로 인한 단락 가능성.\n- 외부 열원에 의한 피복 용융 및 소선 노출 가능성.\n\n---"
#     },
#     "_analysis_status": "COMPLETED",
#     "_instruction_for_agent": "Analysis successfully completed. DO NOT CALL tool again. Use this result to generate the Final Answer immediately."
#   }
# }

# %%
# 5. 분석 결과 시각화 (AI 검출 위치 표시)
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import io
import numpy as np

def draw_bounding_boxes(image_path, analysis_results):
    """
    분석 결과에 포함된 Bounding Box를 이미지 위에 표시합니다.
    """
    try:
        # 이미지 로드
        img = Image.open(image_path)
        original_width, original_height = img.size
        
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(img)
        ax.set_title("AI Detected Regions", fontsize=15)
        axis_off = True
        
        colors = {'step1': 'red', 'step2': 'orange', 'step3': 'blue', 'step4': 'green'}
        labels = {'step1': 'Step 1', 'step2': 'Step 2', 'step3': 'Step 3', 'step4': 'Step 4'}
        
        legend_patches = []
        
        # 각 단계별 결과 시각화
        for step_key, color in colors.items():
            step_result = analysis_results.get(step_key, {})
            bboxes = step_result.get('bboxes', [])
            
            if bboxes:
                axis_off = False
                legend_patches.append(patches.Patch(color=color, label=f"{labels[step_key]} ({len(bboxes)})"))
                
                for box in bboxes:
                    # 0-1000 정규화 좌표 -> 픽셀 좌표 변환
                    # box format: [ymin, xmin, ymax, xmax]
                    ymin, xmin, ymax, xmax = box
                    
                    x = xmin / 1000 * original_width
                    y = ymin / 1000 * original_height
                    w = (xmax - xmin) / 1000 * original_width
                    h = (ymax - ymin) / 1000 * original_height
                    
                    # 사각형 그리기
                    rect = patches.Rectangle((x, y), w, h, linewidth=2, edgecolor=color, facecolor='none')
                    ax.add_patch(rect)

        if legend_patches:
            ax.legend(handles=legend_patches, loc='upper right')
            
        plt.axis('off')
        plt.show()
        
        if not legend_patches:
            print("검출된 Bounding Box 정보가 없습니다.")
            
    except Exception as e:
        print(f"시각화 중 오류 발생: {e}")

# 시각화 함수 실행
if 'test_image_path' in locals() and 'result' in locals():
    # 결과에서 전문가 키 찾기 (동적)
    expert_results = result.get("expert_analysis_results", {})
    target_key = next(iter(expert_results), None) # 첫 번째 키 사용
    
    if target_key:
        print(f"Visualizing results for expert: {target_key}")
        analysis_results = expert_results[target_key]
        draw_bounding_boxes(test_image_path, analysis_results)
    else:
        print("분석 결과(expert_analysis_results)가 비어 있습니다.")
else:
    print("테스트 이미지 경로 또는 분석 결과가 없습니다.")
